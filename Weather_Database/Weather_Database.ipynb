# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# create random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#add latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# use citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# import datetime module from datetime library
from datetime import datetime

# import requests library
import requests

# import API key
from config import weather_api_key

# %%
# starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=8bce802f60bc75d38652850bc2d5b16d

# %%
#create a list for holding cities
cities = []

# identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if city is unique add to cities list
    if city not in cities:
        cities.append(city)

#print city count to confirm sufficient count
len(cities)
# Out:
# 618

# %%
# create an empty list to hold weather data
city_data = []

# print beginning of the log session
print("Beginning of Data Retrieval        ")
print("-----------------------------------")

# create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning of Data Retrieval
# -----------------------------------
# Processing Record 1 of Set 1 | tambopata
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | darhan
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | pevek
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | llata
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | hilo
# Processing Record 15 of Set 1 | pringsewu
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | davila
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | safranbolu
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | tatawin
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 1 | barrow
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | taoudenni
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | willowmore
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | bayan
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | inhambane
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | kasongo-lunda
# Processing Record 45 of Set 1 | miyang
# Processing Record 46 of Set 1 | lasa
# Processing Record 47 of Set 1 | amapa
# Processing Record 48 of Set 1 | saint-louis
# Processing Record 49 of Set 1 | lodwar
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | canatlan
# Processing Record 2 of Set 2 | palmeira
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | najran
# Processing Record 5 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 2 | faya
# Processing Record 7 of Set 2 | lata
# Processing Record 8 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | dakar
# Processing Record 11 of Set 2 | bambanglipuro
# Processing Record 12 of Set 2 | zyryanka
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | hambantota
# Processing Record 15 of Set 2 | pointe michel
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | nemuro
# Processing Record 21 of Set 2 | kenai
# Processing Record 22 of Set 2 | mahajanga
# Processing Record 23 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 2 | la palma
# Processing Record 25 of Set 2 | maues
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | sao filipe
# Processing Record 29 of Set 2 | basco
# Processing Record 30 of Set 2 | iskateley
# Processing Record 31 of Set 2 | laguna
# Processing Record 32 of Set 2 | mount gambier
# Processing Record 33 of Set 2 | surt
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | sehithwa
# Processing Record 36 of Set 2 | chuy
# Processing Record 37 of Set 2 | lebu
# Processing Record 38 of Set 2 | kruisfontein
# Processing Record 39 of Set 2 | healdsburg
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | sawtell
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | padang
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | porto de moz
# Processing Record 46 of Set 2 | neiafu
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | beyneu
# Processing Record 49 of Set 2 | flagstaff
# Processing Record 50 of Set 2 | lakselv
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | asau
# Processing Record 3 of Set 3 | poyarkovo
# Processing Record 4 of Set 3 | santa cruz
# Processing Record 5 of Set 3 | altay
# Processing Record 6 of Set 3 | kawalu
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | narsaq
# Processing Record 10 of Set 3 | la ronge
# Processing Record 11 of Set 3 | mareeba
# Processing Record 12 of Set 3 | benghazi
# Processing Record 13 of Set 3 | seymchan
# Processing Record 14 of Set 3 | chardara
# Processing Record 15 of Set 3 | tazovskiy
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | tabou
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | mala
# Processing Record 21 of Set 3 | inta
# Processing Record 22 of Set 3 | melfi
# Processing Record 23 of Set 3 | fereydun kenar
# Processing Record 24 of Set 3 | abu kamal
# Processing Record 25 of Set 3 | stornoway
# Processing Record 26 of Set 3 | kotido
# Processing Record 27 of Set 3 | los alamos
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | saint-philippe
# Processing Record 31 of Set 3 | luceville
# City not found. Skipping...
# Processing Record 32 of Set 3 | zainsk
# Processing Record 33 of Set 3 | temyasovo
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | sumenep
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | thurso
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | kavieng
# Processing Record 40 of Set 3 | savonlinna
# Processing Record 41 of Set 3 | poum
# Processing Record 42 of Set 3 | ust-maya
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | lahij
# Processing Record 46 of Set 3 | beidao
# Processing Record 47 of Set 3 | cowra
# Processing Record 48 of Set 3 | harnosand
# Processing Record 49 of Set 3 | buriti dos lopes
# Processing Record 50 of Set 3 | iqaluit
# Processing Record 1 of Set 4 | severo-kurilsk
# Processing Record 2 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 4 | sawakin
# Processing Record 4 of Set 4 | kochki
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | yar-sale
# Processing Record 7 of Set 4 | itarema
# Processing Record 8 of Set 4 | vilyuysk
# Processing Record 9 of Set 4 | itoman
# Processing Record 10 of Set 4 | beihai
# Processing Record 11 of Set 4 | vanimo
# Processing Record 12 of Set 4 | ola
# Processing Record 13 of Set 4 | ocampo
# Processing Record 14 of Set 4 | melfort
# Processing Record 15 of Set 4 | port hedland
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | shieli
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | bilibino
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | kardla
# Processing Record 23 of Set 4 | severobaykalsk
# Processing Record 24 of Set 4 | north bend
# Processing Record 25 of Set 4 | tura
# Processing Record 26 of Set 4 | baruun-urt
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | tulun
# Processing Record 29 of Set 4 | ambon
# Processing Record 30 of Set 4 | matagami
# Processing Record 31 of Set 4 | srednekolymsk
# Processing Record 32 of Set 4 | codrington
# Processing Record 33 of Set 4 | ixtapa
# Processing Record 34 of Set 4 | chokurdakh
# Processing Record 35 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 36 of Set 4 | banepa
# Processing Record 37 of Set 4 | tiarei
# Processing Record 38 of Set 4 | high level
# Processing Record 39 of Set 4 | lagoa
# Processing Record 40 of Set 4 | buraydah
# Processing Record 41 of Set 4 | tommot
# Processing Record 42 of Set 4 | tual
# Processing Record 43 of Set 4 | mao
# Processing Record 44 of Set 4 | arrifes
# Processing Record 45 of Set 4 | urucara
# Processing Record 46 of Set 4 | san carlos de bariloche
# Processing Record 47 of Set 4 | kjollefjord
# Processing Record 48 of Set 4 | ouesso
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 1 of Set 5 | shahreza
# Processing Record 2 of Set 5 | faanui
# Processing Record 3 of Set 5 | east london
# Processing Record 4 of Set 5 | nyurba
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | awbari
# Processing Record 8 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 5 | atherton
# Processing Record 10 of Set 5 | sira
# Processing Record 11 of Set 5 | nioki
# Processing Record 12 of Set 5 | hithadhoo
# Processing Record 13 of Set 5 | alofi
# Processing Record 14 of Set 5 | aras
# Processing Record 15 of Set 5 | glenwood springs
# Processing Record 16 of Set 5 | umm kaddadah
# Processing Record 17 of Set 5 | chase
# Processing Record 18 of Set 5 | vaitape
# Processing Record 19 of Set 5 | mariakani
# Processing Record 20 of Set 5 | konin
# Processing Record 21 of Set 5 | mount isa
# Processing Record 22 of Set 5 | kijang
# Processing Record 23 of Set 5 | miraflores
# Processing Record 24 of Set 5 | point pedro
# Processing Record 25 of Set 5 | canico
# Processing Record 26 of Set 5 | minador do negrao
# Processing Record 27 of Set 5 | tuktoyaktuk
# Processing Record 28 of Set 5 | urumqi
# Processing Record 29 of Set 5 | norman wells
# Processing Record 30 of Set 5 | broken hill
# Processing Record 31 of Set 5 | maumere
# Processing Record 32 of Set 5 | a
# City not found. Skipping...
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | mikasa
# Processing Record 35 of Set 5 | yumen
# Processing Record 36 of Set 5 | luderitz
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | maragogi
# Processing Record 39 of Set 5 | mayor pablo lagerenza
# Processing Record 40 of Set 5 | igrim
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | ust-omchug
# Processing Record 43 of Set 5 | saldanha
# Processing Record 44 of Set 5 | berlevag
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | cockburn town
# Processing Record 47 of Set 5 | ahuimanu
# Processing Record 48 of Set 5 | yazykovo
# Processing Record 49 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 50 of Set 5 | dongying
# Processing Record 1 of Set 6 | aqtobe
# Processing Record 2 of Set 6 | ponta do sol
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | arman
# Processing Record 5 of Set 6 | kungurtug
# Processing Record 6 of Set 6 | ketchikan
# Processing Record 7 of Set 6 | comodoro rivadavia
# Processing Record 8 of Set 6 | charters towers
# Processing Record 9 of Set 6 | camana
# Processing Record 10 of Set 6 | moramanga
# Processing Record 11 of Set 6 | port elizabeth
# Processing Record 12 of Set 6 | baikunthpur
# Processing Record 13 of Set 6 | miri
# Processing Record 14 of Set 6 | rio grande
# Processing Record 15 of Set 6 | gawler
# Processing Record 16 of Set 6 | great bend
# Processing Record 17 of Set 6 | xuddur
# Processing Record 18 of Set 6 | lavrentiya
# Processing Record 19 of Set 6 | komsomolskiy
# Processing Record 20 of Set 6 | mezen
# Processing Record 21 of Set 6 | cayenne
# Processing Record 22 of Set 6 | kabo
# Processing Record 23 of Set 6 | kaitangata
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | guerrero negro
# Processing Record 27 of Set 6 | ankang
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | kouango
# Processing Record 30 of Set 6 | rio gallegos
# Processing Record 31 of Set 6 | riyadh
# Processing Record 32 of Set 6 | provideniya
# Processing Record 33 of Set 6 | paamiut
# Processing Record 34 of Set 6 | pacocha
# Processing Record 35 of Set 6 | awjilah
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | sampit
# Processing Record 38 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 39 of Set 6 | taltal
# Processing Record 40 of Set 6 | karratha
# Processing Record 41 of Set 6 | kamiiso
# Processing Record 42 of Set 6 | khuzdar
# Processing Record 43 of Set 6 | kalevala
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | sabla
# Processing Record 46 of Set 6 | mogadishu
# Processing Record 47 of Set 6 | muros
# Processing Record 48 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 6 | ostersund
# Processing Record 50 of Set 6 | swan hill
# Processing Record 1 of Set 7 | zhanaozen
# Processing Record 2 of Set 7 | sucua
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | chapais
# Processing Record 5 of Set 7 | port blair
# Processing Record 6 of Set 7 | kutum
# Processing Record 7 of Set 7 | zambezi
# Processing Record 8 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 7 | saint george
# Processing Record 10 of Set 7 | bandarbeyla
# Processing Record 11 of Set 7 | batemans bay
# Processing Record 12 of Set 7 | ajmer
# Processing Record 13 of Set 7 | evensk
# Processing Record 14 of Set 7 | dehloran
# Processing Record 15 of Set 7 | vagur
# Processing Record 16 of Set 7 | tshikapa
# Processing Record 17 of Set 7 | tiznit
# Processing Record 18 of Set 7 | parana
# Processing Record 19 of Set 7 | guspini
# Processing Record 20 of Set 7 | parrita
# Processing Record 21 of Set 7 | maryborough
# Processing Record 22 of Set 7 | necochea
# Processing Record 23 of Set 7 | hargeysa
# Processing Record 24 of Set 7 | fochville
# Processing Record 25 of Set 7 | touros
# Processing Record 26 of Set 7 | roald
# Processing Record 27 of Set 7 | kodiak
# Processing Record 28 of Set 7 | jalu
# Processing Record 29 of Set 7 | laela
# Processing Record 30 of Set 7 | longyearbyen
# Processing Record 31 of Set 7 | vestmannaeyjar
# Processing Record 32 of Set 7 | crotone
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | kyaukse
# Processing Record 35 of Set 7 | two rivers
# Processing Record 36 of Set 7 | acapulco
# Processing Record 37 of Set 7 | hofn
# Processing Record 38 of Set 7 | vlissingen
# Processing Record 39 of Set 7 | svirstroy
# Processing Record 40 of Set 7 | dien bien
# City not found. Skipping...
# Processing Record 41 of Set 7 | nuevo imperial
# Processing Record 42 of Set 7 | mchinji
# Processing Record 43 of Set 7 | pangnirtung
# Processing Record 44 of Set 7 | torbay
# Processing Record 45 of Set 7 | el dorado
# Processing Record 46 of Set 7 | hays
# Processing Record 47 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 48 of Set 7 | luena
# Processing Record 49 of Set 7 | aswan
# Processing Record 50 of Set 7 | iringa
# Processing Record 1 of Set 8 | whyalla
# Processing Record 2 of Set 8 | khatanga
# Processing Record 3 of Set 8 | katangli
# Processing Record 4 of Set 8 | champerico
# Processing Record 5 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 8 | sembe
# Processing Record 7 of Set 8 | atar
# Processing Record 8 of Set 8 | inirida
# Processing Record 9 of Set 8 | norden
# Processing Record 10 of Set 8 | suratgarh
# Processing Record 11 of Set 8 | nijar
# Processing Record 12 of Set 8 | nunoa
# Processing Record 13 of Set 8 | hoi an
# Processing Record 14 of Set 8 | kulhudhuffushi
# Processing Record 15 of Set 8 | westport
# Processing Record 16 of Set 8 | sambava
# Processing Record 17 of Set 8 | krasnovishersk
# Processing Record 18 of Set 8 | nkowakowa
# Processing Record 19 of Set 8 | mandalgovi
# Processing Record 20 of Set 8 | benjamin hill
# Processing Record 21 of Set 8 | katsuura
# Processing Record 22 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | namatanai
# Processing Record 25 of Set 8 | gravdal
# Processing Record 26 of Set 8 | flin flon
# Processing Record 27 of Set 8 | zhigansk
# Processing Record 28 of Set 8 | kampene
# Processing Record 29 of Set 8 | broome
# Processing Record 30 of Set 8 | tupik
# Processing Record 31 of Set 8 | pitsunda
# Processing Record 32 of Set 8 | port hueneme
# Processing Record 33 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 34 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 8 | itaituba
# Processing Record 36 of Set 8 | matameye
# City not found. Skipping...
# Processing Record 37 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 38 of Set 8 | guayaquil
# Processing Record 39 of Set 8 | beni
# Processing Record 40 of Set 8 | siirt
# Processing Record 41 of Set 8 | yabelo
# Processing Record 42 of Set 8 | kurilsk
# Processing Record 43 of Set 8 | granby
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | amasia
# Processing Record 46 of Set 8 | edd
# Processing Record 47 of Set 8 | oyama
# Processing Record 48 of Set 8 | novopokrovka
# Processing Record 49 of Set 8 | ndjole
# Processing Record 50 of Set 8 | praya
# Processing Record 1 of Set 9 | simao
# Processing Record 2 of Set 9 | ancud
# Processing Record 3 of Set 9 | camacha
# Processing Record 4 of Set 9 | klaksvik
# Processing Record 5 of Set 9 | chuka
# Processing Record 6 of Set 9 | samarai
# Processing Record 7 of Set 9 | williams lake
# Processing Record 8 of Set 9 | henties bay
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | valverde del camino
# Processing Record 11 of Set 9 | nueva italia de ruiz
# Processing Record 12 of Set 9 | smardan
# Processing Record 13 of Set 9 | west bay
# Processing Record 14 of Set 9 | zhitikara
# City not found. Skipping...
# Processing Record 15 of Set 9 | kloulklubed
# Processing Record 16 of Set 9 | vitim
# Processing Record 17 of Set 9 | segou
# Processing Record 18 of Set 9 | talcahuano
# Processing Record 19 of Set 9 | tourlaville
# Processing Record 20 of Set 9 | krasnoselkup
# Processing Record 21 of Set 9 | xai-xai
# Processing Record 22 of Set 9 | jiguani
# Processing Record 23 of Set 9 | saskylakh
# Processing Record 24 of Set 9 | carnarvon
# Processing Record 25 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 9 | aripuana
# Processing Record 29 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 9 | abiy adi
# City not found. Skipping...
# Processing Record 31 of Set 9 | dunedin
# Processing Record 32 of Set 9 | mayo
# Processing Record 33 of Set 9 | laredo
# Processing Record 34 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 35 of Set 9 | salmas
# Processing Record 36 of Set 9 | uppsala
# Processing Record 37 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 9 | sulangan
# Processing Record 39 of Set 9 | nishihara
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | rocha
# Processing Record 42 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 44 of Set 9 | ulaangom
# Processing Record 45 of Set 9 | yeniseysk
# Processing Record 46 of Set 9 | hirara
# Processing Record 47 of Set 9 | lucapa
# Processing Record 48 of Set 9 | kahului
# Processing Record 49 of Set 9 | banda aceh
# Processing Record 50 of Set 9 | talnakh
# Processing Record 1 of Set 10 | biak
# Processing Record 2 of Set 10 | kracheh
# City not found. Skipping...
# Processing Record 3 of Set 10 | vila velha
# Processing Record 4 of Set 10 | ishigaki
# Processing Record 5 of Set 10 | dingzhou
# Processing Record 6 of Set 10 | napa
# Processing Record 7 of Set 10 | zafarwal
# Processing Record 8 of Set 10 | soure
# Processing Record 9 of Set 10 | ariquemes
# Processing Record 10 of Set 10 | mahebourg
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | kirkuk
# Processing Record 13 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 10 | chumikan
# Processing Record 15 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 10 | jieshi
# Processing Record 17 of Set 10 | ramona
# Processing Record 18 of Set 10 | palauig
# Processing Record 19 of Set 10 | botou
# Processing Record 20 of Set 10 | walvis bay
# Processing Record 21 of Set 10 | makung
# City not found. Skipping...
# Processing Record 22 of Set 10 | shouguang
# Processing Record 23 of Set 10 | san juan
# Processing Record 24 of Set 10 | tezpur
# Processing Record 25 of Set 10 | baiyin
# Processing Record 26 of Set 10 | salalah
# Processing Record 27 of Set 10 | sucre
# Processing Record 28 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 10 | lambare
# Processing Record 30 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 10 | derzhavinsk
# Processing Record 32 of Set 10 | puerto escondido
# Processing Record 33 of Set 10 | constantine
# Processing Record 34 of Set 10 | zharkent
# Processing Record 35 of Set 10 | ferkessedougou
# Processing Record 36 of Set 10 | morondava
# Processing Record 37 of Set 10 | wa
# City not found. Skipping...
# Processing Record 38 of Set 10 | plettenberg bay
# Processing Record 39 of Set 10 | naze
# Processing Record 40 of Set 10 | leeuwarden
# Processing Record 41 of Set 10 | kem
# Processing Record 42 of Set 10 | ormos korthiou
# City not found. Skipping...
# Processing Record 43 of Set 10 | bontang
# Processing Record 44 of Set 10 | arica
# Processing Record 45 of Set 10 | sitka
# Processing Record 46 of Set 10 | nuuk
# Processing Record 47 of Set 10 | porto novo
# Processing Record 48 of Set 10 | esik
# Processing Record 49 of Set 10 | baoro
# Processing Record 50 of Set 10 | kysyl-syr
# Processing Record 1 of Set 11 | bria
# Processing Record 2 of Set 11 | bosansko grahovo
# Processing Record 3 of Set 11 | palaia fokaia
# Processing Record 4 of Set 11 | moses lake
# Processing Record 5 of Set 11 | gasa
# Processing Record 6 of Set 11 | ascope
# Processing Record 7 of Set 11 | bacuit
# City not found. Skipping...
# Processing Record 8 of Set 11 | mbandaka
# Processing Record 9 of Set 11 | makakilo city
# Processing Record 10 of Set 11 | kattivakkam
# Processing Record 11 of Set 11 | krasnokholm
# Processing Record 12 of Set 11 | san cristobal
# Processing Record 13 of Set 11 | krasnoshchekovo
# Processing Record 14 of Set 11 | lac du bonnet
# Processing Record 15 of Set 11 | talavera
# Processing Record 16 of Set 11 | akdepe
# Processing Record 17 of Set 11 | okha
# Processing Record 18 of Set 11 | gaoua
# Processing Record 19 of Set 11 | margate
# Processing Record 20 of Set 11 | sao domingos
# Processing Record 21 of Set 11 | poya
# Processing Record 22 of Set 11 | okhotsk
# Processing Record 23 of Set 11 | pemangkat
# Processing Record 24 of Set 11 | vao
# Processing Record 25 of Set 11 | dalvik
# Processing Record 26 of Set 11 | pucallpa
# Processing Record 27 of Set 11 | saint-joseph
# Processing Record 28 of Set 11 | wucheng
# Processing Record 29 of Set 11 | esil
# Processing Record 30 of Set 11 | clarence town
# Processing Record 31 of Set 11 | asyut
# Processing Record 32 of Set 11 | hami
# Processing Record 33 of Set 11 | dawlatabad
# Processing Record 34 of Set 11 | gat
# Processing Record 35 of Set 11 | pailon
# Processing Record 36 of Set 11 | basoko
# Processing Record 37 of Set 11 | storsteinnes
# Processing Record 38 of Set 11 | constitucion
# Processing Record 39 of Set 11 | ostrovnoy
# Processing Record 40 of Set 11 | nago
# Processing Record 41 of Set 11 | san pedro
# Processing Record 42 of Set 11 | waipawa
# Processing Record 43 of Set 11 | porto nacional
# Processing Record 44 of Set 11 | bafoussam
# Processing Record 45 of Set 11 | kudahuvadhoo
# Processing Record 46 of Set 11 | yen bai
# Processing Record 47 of Set 11 | skibbereen
# Processing Record 48 of Set 11 | tucumcari
# Processing Record 49 of Set 11 | pervomayskoye
# Processing Record 50 of Set 11 | qurunbaliyah
# City not found. Skipping...
# Processing Record 1 of Set 12 | krasnyy chikoy
# Processing Record 2 of Set 12 | saint-pierre
# Processing Record 3 of Set 12 | ambarawa
# Processing Record 4 of Set 12 | guayaramerin
# Processing Record 5 of Set 12 | atambua
# Processing Record 6 of Set 12 | nosy varika
# Processing Record 7 of Set 12 | changji
# Processing Record 8 of Set 12 | jati
# Processing Record 9 of Set 12 | santa fe
# Processing Record 10 of Set 12 | sangar
# Processing Record 11 of Set 12 | kamogawa
# Processing Record 12 of Set 12 | punta cardon
# Processing Record 13 of Set 12 | banswara
# Processing Record 14 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 15 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 12 | san patricio
# Processing Record 17 of Set 12 | karpogory
# Processing Record 18 of Set 12 | moron
# Processing Record 19 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 12 | saravan
# Processing Record 21 of Set 12 | gizo
# Processing Record 22 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 12 | fukue
# Processing Record 24 of Set 12 | menongue
# Processing Record 25 of Set 12 | isangel
# Processing Record 26 of Set 12 | sovetskiy
# Processing Record 27 of Set 12 | kropotkin
# Processing Record 28 of Set 12 | sioux lookout
# Processing Record 29 of Set 12 | slave lake
# Processing Record 30 of Set 12 | alyangula
# Processing Record 31 of Set 12 | ulladulla
# Processing Record 32 of Set 12 | petrykivka
# Processing Record 33 of Set 12 | jiayuguan
# Processing Record 34 of Set 12 | husavik
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | oksfjord
# Processing Record 37 of Set 12 | sistranda
# Processing Record 38 of Set 12 | muisne
# Processing Record 39 of Set 12 | sisophon
# Processing Record 40 of Set 12 | aasiaat
# Processing Record 41 of Set 12 | olinda
# Processing Record 42 of Set 12 | villa bruzual
# Processing Record 43 of Set 12 | alice springs
# Processing Record 44 of Set 12 | leh
# Processing Record 45 of Set 12 | coihaique
# Processing Record 46 of Set 12 | pemberton
# Processing Record 47 of Set 12 | neuquen
# Processing Record 48 of Set 12 | saint-francois
# Processing Record 49 of Set 12 | la asuncion
# Processing Record 50 of Set 12 | chadan
# Processing Record 1 of Set 13 | biltine
# Processing Record 2 of Set 13 | huaiyin
# Processing Record 3 of Set 13 | mende
# Processing Record 4 of Set 13 | xichang
# Processing Record 5 of Set 13 | nekhayevskiy
# Processing Record 6 of Set 13 | matay
# Processing Record 7 of Set 13 | yuanping
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | leamington
# Processing Record 10 of Set 13 | sinnamary
# Processing Record 11 of Set 13 | pribelskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | semey
# Processing Record 13 of Set 13 | kiama
# Processing Record 14 of Set 13 | minab
# Processing Record 15 of Set 13 | belmonte
# Processing Record 16 of Set 13 | kitakata
# Processing Record 17 of Set 13 | buala
# Processing Record 18 of Set 13 | bubaque
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Tambopata -12.7333  -69.1833     85.95        44          92
# 1      Yellowknife  62.4560 -114.3525     42.57        87          20
# 2           Hobart -42.8794  147.3294     59.11        47          20
# 3     Puerto Ayora  -0.7393  -90.3518     69.22        90          87
# 4     Punta Arenas -53.1500  -70.9167     41.11        81           0
# 5          Rikitea -23.1203 -134.9692     73.65        72          33
# 6           Darhan  49.4867  105.9228     46.17        51          93
# 7            Kapaa  22.0752 -159.3190     84.18        75          40
# 8  Arraial Do Cabo -22.9661  -42.0278     71.08        87          86
# 9            Pevek  69.7008  170.3133     31.89        89         100
#
#    Wind Speed Country                 Date
# 0        1.36      PE  2021-09-27 02:42:14
# 1        4.61      CA  2021-09-27 02:34:29
# 2        4.00      AU  2021-09-27 02:38:28
# 3        6.91      EC  2021-09-27 02:38:11
# 4       12.66      CL  2021-09-27 02:37:33
# 5       19.60      PF  2021-09-27 02:38:14
# 6        2.57      MN  2021-09-27 02:42:15
# 7        7.00      US  2021-09-27 02:35:42
# 8       22.15      BR  2021-09-27 02:42:16
# 9       23.04      RU  2021-09-27 02:38:26

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'

#export city_data into a CSV
city_data_df
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tambopata -12.7333  -69.1833     85.95        44          92
# 1     Yellowknife  62.4560 -114.3525     42.57        87          20
# 2          Hobart -42.8794  147.3294     59.11        47          20
# 3    Puerto Ayora  -0.7393  -90.3518     69.22        90          87
# 4    Punta Arenas -53.1500  -70.9167     41.11        81           0
# ..            ...      ...       ...       ...       ...         ...
# 560         Minab  27.1467   57.0801     81.90        79          56
# 561      Belmonte -15.8631  -38.8828     73.90        89          77
# 562      Kitakata  37.6500  139.8667     68.11        64          60
# 563         Buala  -8.1450  159.5921     84.51        68          69
# 564       Bubaque  11.2833  -15.8333     83.01        79          97
#
#      Wind Speed Country                 Date
# 0          1.36      PE  2021-09-27 02:42:14
# 1          4.61      CA  2021-09-27 02:34:29
# 2          4.00      AU  2021-09-27 02:38:28
# 3          6.91      EC  2021-09-27 02:38:11
# 4         12.66      CL  2021-09-27 02:37:33
# ..          ...     ...                  ...
# 560        2.71      IR  2021-09-27 02:45:44
# 561        6.78      BR  2021-09-27 02:45:45
# 562        6.02      JP  2021-09-27 02:45:45
# 563        5.35      SB  2021-09-27 02:45:46
# 564        9.08      GW  2021-09-27 02:45:46
#
# [565 rows x 9 columns]

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 3.5 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.9

# %%
city_data_df.to_excel('weather.xlsx')
